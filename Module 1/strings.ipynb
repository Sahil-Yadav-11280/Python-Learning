# %%
"15632147" #string
"%$*&^#@" #string
Name = "Michael Jackson" #string

# %% [markdown]
# #### Indexing
#
# Positive Indexing
# <img src="./Images/indexing1.png">
#
# Negative Indexing
# <img src="./Images/indexing2.png">
#
# Slicing:

# %%
# Select variable from index 0 to index 3
print(Name[0:4])

# Select variable from index 8 to index 11
print(Name[8:12])

# Select every 2nd variable from all indexes
print(Name[::2])

# Similarly.
print(Name[0:5:2])
# Out:
# Mich
# Jack
# McalJcsn
# Mca

# %%
# to get length
len(Name)
# Out:
# 15

# %%
# Concatenation
Statement = Name + " is the best!"
print(Statement)
# Out:
# Michael Jackson is the best!

# %%
# String replecation
3*Name
Name*3
# Out:
# 'Michael JacksonMichael JacksonMichael Jackson'

# %% [markdown]
# Strings are immutable , you cannot alter the strings but create a new one

# %%
Name = "Michael Jackson"
Name[0] = "J" #NOT Allowed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 Name = "Michael Jackson"
# ----> 2 Name[0] = "J" #NOT Allowed
#
# TypeError: 'str' object does not support item assignment

# %%
# Creating a new string with the old one
Name = Name + " is the best!"
print(Name)
# Out:
# Michael Jackson is the best!

# %% [markdown]
# \ are used for escape sequences
# 1. Escape sequences are strings that re difficult to input

# %%
# ex:
print("Michael Jackson \nis the best!")

# \t represents tab
print("Michael Jackson \tis the best!")

# \\ represent \
print("Michael Jackson \\ is the best")
# Out:
# Michael Jackson
# is the best!
# Michael Jackson 	is the best!
# Michael Jackson \ is the best

# %% [markdown]
# An r can also be placed in front of string instead of escape sequences

# %%
print(r"Michael jackson \ is the best")
# Out:
# Michael jackson \ is the best

# %% [markdown]
# Methods:
# 1. String contains 2 types of methods , one for lists and tuples other for strings exclusively
# 2. String methods convert a part of string and store in a new one
# 3. Some string methods are:

# %%
A = "Michael Jackson is the best!"
print(A.upper())
print(A.replace("Michael" , "Janet"))
print(A.find("el")) # finds substring in a string
# if substring is not in string then output is -1
print(A.find("Sahil"))
# Out:
# MICHAEL JACKSON IS THE BEST!
# Janet Jackson is the best!
# 5
# -1

# %%
article_title = "data science basics"
print(article_title.title())
# Out:
# Data Science Basics

# %%
"hello".title()
# Out:
# 'Hello'

# %%
def freq(string,passedkey):

    #step1: A list variable is declared and initialized to an empty list.
    words = []

    #step2: Break the string into list of words
    words = string.split() # or string.lower().split()

    #step3: Declare a dictionary
    Dict = {}

    #step4: Use for loop to iterate words and values to the dictionary
    for key in words:
        if(key == passedkey):
            Dict[key] = words.count(key)   
    #step5: Print the dictionary
    print("Total Count:",Dict)

#step6: Call function and pass string in it
freq("Mary had a little lamb Little lamb, little lamb Mary had a little lamb.Its fleece was white as snow And everywhere that Mary went Mary went, Mary went \
Everywhere that Mary went The lamb was sure to go","little")
# Out:
# Total Count: {'little': 3}
